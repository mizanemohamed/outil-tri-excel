# %%
import pandas as pd

# %%
data = pd.read_excel('CréditBanc.xlsx')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Client ID                611 non-null    object
#  1   Sexe                     601 non-null    object
#  2   Situation familiale      611 non-null    object
#  3   Personnes charge         599 non-null    float64
#  4   Diplome                  605 non-null    object
#  5   Travailleur independant  580 non-null    object
#  6   Revenu imposable         610 non-null    float64
#  7   Revenu forfitaire        610 non-null    float64
#  8   Montant pret             591 non-null    float64
#  9   Duree pret               598 non-null    float64
#  10  Hitorique credit         564 non-null    float64
#  11  Residence                612 non-null    object
#  12  Decision                 614 non-null    object
# dtypes: float64(6), object(7)
# memory usage: 62.5+ KB

# %%
data.head()
# Out:
#   Client ID  Sexe Situation familiale  Personnes charge       Diplome  \
# 0  LP001002  Male                  No               0.0      Graduate
# 1  LP001003  Male                 Yes               1.0      Graduate
# 2  LP001005  Male                 Yes               0.0      Graduate
# 3  LP001006  Male                 Yes               0.0  Not Graduate
# 4  LP001008  Male                  No               0.0      Graduate
#
#   Travailleur independant  Revenu imposable  Revenu forfitaire  Montant pret  \
# 0                      No            5849.0                0.0           NaN
# 1                      No            4583.0             1508.0         128.0
# 2                     Yes            3000.0                0.0          66.0
# 3                      No            2583.0             2358.0         120.0
# 4                      No            6000.0                0.0         141.0
#
#    Duree pret  Hitorique credit Residence Decision
# ...

# %%
data.shape
# Out:
# (614, 13)

# %%
data_null = data.isna().sum().to_frame()
data_null.T
# Out:
#    Client ID  Sexe  Situation familiale  Personnes charge  Diplome  \
# 0          3    13                    3                15        9
#
#    Travailleur independant  Revenu imposable  Revenu forfitaire  Montant pret  \
# 0                       34                 4                  4            23
#
#    Duree pret  Hitorique credit  Residence  Decision
# 0          16                50          2         0

# %%
data_mod = data.copy()

# %%
new_columns = ({'Client ID': 'Client_ID','Situation familiale':'Situation_familiale','Personnes charge':'Personnes_charge','Travailleur independant':'Travailleur_independant','Revenu imposable':'Revenu_imposable','Revenu forfitaire':'Revenu_forfitaire','Montant pret':'Montant_pret','Duree pret':'Duree_pret','Hitorique credit':'Hitorique_credit'})

# %%
data_mod.rename(columns=new_columns, inplace=True)

# %%
data_mod.head()
# Out:
#   Client_ID  Sexe Situation_familiale  Personnes_charge       Diplome  \
# 0  LP001002  Male                  No               0.0      Graduate
# 1  LP001003  Male                 Yes               1.0      Graduate
# 2  LP001005  Male                 Yes               0.0      Graduate
# 3  LP001006  Male                 Yes               0.0  Not Graduate
# 4  LP001008  Male                  No               0.0      Graduate
#
#   Travailleur_independant  Revenu_imposable  Revenu_forfitaire  Montant_pret  \
# 0                      No            5849.0                0.0           NaN
# 1                      No            4583.0             1508.0         128.0
# 2                     Yes            3000.0                0.0          66.0
# 3                      No            2583.0             2358.0         120.0
# 4                      No            6000.0                0.0         141.0
#
#    Duree_pret  Hitorique_credit Residence Decision
# ...

# %%
data_mod.dropna()
# Out:
#     Client_ID    Sexe Situation_familiale  Personnes_charge       Diplome  \
# 1    LP001003    Male                 Yes               1.0      Graduate
# 2    LP001005    Male                 Yes               0.0      Graduate
# 3    LP001006    Male                 Yes               0.0  Not Graduate
# 4    LP001008    Male                  No               0.0      Graduate
# 5    LP001011    Male                 Yes               2.0      Graduate
# ..        ...     ...                 ...               ...           ...
# 606  LP002961    Male                 Yes               1.0      Graduate
# 607  LP002964    Male                 Yes               2.0  Not Graduate
# 609  LP002978  Female                  No               0.0      Graduate
# 612  LP002984    Male                 Yes               2.0      Graduate
# 613  LP002990  Female                  No               0.0      Graduate
#
#     Travailleur_independant  Revenu_imposable  Revenu_forfitaire  \
# ...

# %%
data_mod.dropna().isnull().sum()
# Out:
# Client_ID                  0
# Sexe                       0
# Situation_familiale        0
# Personnes_charge           0
# Diplome                    0
# Travailleur_independant    0
# Revenu_imposable           0
# Revenu_forfitaire          0
# Montant_pret               0
# Duree_pret                 0
# Hitorique_credit           0
# Residence                  0
# Decision                   0
# dtype: int64
